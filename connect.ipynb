# %%
#%pip install -e /home/bram/work/qcapi


from qcapi import QcapiConfig, QiskitRuntimeRestClient
cfg = QcapiConfig.load()
client = QiskitRuntimeRestClient(cfg)
print(client.list_backends())
# Out:
# {'devices': [{'name': 'ibm_fez', 'status': {'name': 'online', 'reason': 'available'}, 'qubits': 156, 'clops': {'type': 'hardware', 'value': 320000}, 'processor_type': {'family': 'Heron', 'revision': '2'}, 'queue_length': 190, 'performance_metrics': {'two_q_error_best': {'gate': 'cz', 'qubits': [40, 41], 'unit': '', 'value': 0.0013802423}, 'two_q_error_layered': {'unit': '', 'value': 0.004854708}, 'two_q_error_median': {'unit': '', 'value': 0.0026273502}, 'readout_error_median': {'unit': '', 'value': 0.0138549805}}}, {'name': 'ibm_torino', 'status': {'name': 'online', 'reason': 'available'}, 'qubits': 133, 'clops': {'type': 'hardware', 'value': 290000}, 'processor_type': {'family': 'Heron', 'revision': '1'}, 'queue_length': 0, 'performance_metrics': {'two_q_error_best': {'gate': 'cz', 'qubits': [26, 27], 'unit': '', 'value': 0.0012935072}, 'two_q_error_layered': {'unit': '', 'value': 0.006525324}, 'two_q_error_median': {'unit': '', 'value': 0.0025684156}, 'readout_error_median': {'unit': '', 'value': 0.030639648}}}, {'name': 'ibm_marrakesh', 'status': {'name': 'online', 'reason': 'available'}, 'qubits': 156, 'clops': {'type': 'hardware', 'value': 300000}, 'processor_type': {'family': 'Heron', 'revision': '2'}, 'queue_length': 4, 'performance_metrics': {'two_q_error_best': {'gate': 'cz', 'qubits': [6, 7], 'unit': '', 'value': 0.0010063759}, 'two_q_error_layered': {'unit': '', 'value': 0.0037674538}, 'two_q_error_median': {'unit': '', 'value': 0.002413425}, 'readout_error_median': {'unit': '', 'value': 0.013244629}}}]}
